# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\deban\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\deban\anaconda3\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\deban\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\deban\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\deban\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# FIRST MACHINE LEARNING MODEL

# %%
from sklearn import tree
# step-1  collect data
# features  [weight(grams), color(0=red, 1=orange)]
features=[
    [150,0],#apple
    [170,0],#apple
    [130,1],#orange
    [120,1], #orange    
]
labels=["apple","apple","orange","orange"]

# %% [markdown]
# strp 2 : Train a Model

# %%
clf=tree.DecisionTreeClassifier()
clf=clf.fit(features,labels)

# %%
print(clf.predict([[160, 0]]))  # Heavy and red-ish? Probably an apple!
print(clf.predict([[115, 1]]))  # Light and orange? Probably an orange!
# Out:
# ['apple']
# ['orange']

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(7,6))
plot_tree(clf, feature_names=["weight", "color"], class_names=["apple", "orange"], filled=True)
plt.show()
