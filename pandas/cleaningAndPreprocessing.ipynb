# %%
import pandas as pd

# %%
df=pd.read_csv('data_cleaning_sample.csv')

# %% [markdown]
# checking if the data is null

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %% [markdown]
# Checking how many null  values are there in a column

# %%
df.isnull().sum()  # checking if the data is null
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df.dropna()  # dropping the null values by the row
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df.dropna(axis=1)  # dropping the null values by the column
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %% [markdown]
# fillna()- is put the value zero instead of missing value

# %%
df.fillna(0)  # fillna()- is put the value zero instead of missing value
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5        0  28.0        Delhi      F     eve@domain.com           0
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   0.0        Delhi      M    charlie@example  20-07-2021

# %% [markdown]
# fill the missing value with the mean

# %%
df['Age'].fillna(df['Age'].mean())  # fill the missing value with the mean
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %% [markdown]
# forwardfill= replace the missing value with last number from forward counting
#
#
# backwardfill= replace the missing value with last valuue of backward counting

# %%
df.fillna(method='ffill')  # fillna()- is put the value of previous row instead of missing value
# Out:
# C:\Users\deban\AppData\Local\Temp\ipykernel_18956\1762063713.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')  # fillna()- is put the value of previous row instead of missing value
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# ...

# %%
df.fillna(method='bfill')  # fillna()- is put the value of next row instead of missing value
# Out:
# C:\Users\deban\AppData\Local\Temp\ipykernel_18956\3655049465.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')  # fillna()- is put the value of next row instead of missing value
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# ...

# %% [markdown]
# this method will be depricated so there's a new method wich is the following

# %%
df.ffill()  # this method will be depricated so there's a new method wich is the following
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  25.0        Delhi      M    charlie@example  20-07-2021

# %%
df.bfill()  # this method will be depricated so there's a new method wich is the following
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %% [markdown]
# Detecting and removing dupplicate rows

# %%
df.duplicated()  # Detecting and removing dupplicate rows
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %% [markdown]
# dropping duplicates

# %%
df2=df.drop_duplicates()  # Detecting and removing dupplicate rows

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %% [markdown]
# removing duplicates in the basis of two columns

# %%
 df.duplicated(subset=['Name', 'Age'])  # Detecting and removing dupplicate rows based on specific columns
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %% [markdown]
# String Operations

# %%
df['Name'].str.lower()  # String Operations - converting to lower case
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %% [markdown]
# searching if a string is present or not

# %%
df['City'].str.contains('delhi',case=False)  # String Operations - checking if the string contains 'delhi' in a case-insensitive manner
#case=false makes the search case-insensitive
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: City, dtype: bool

# %% [markdown]
# Type conversion

# %%
df2=df.dropna().copy()  # Creating a copy of the DataFrame after dropping null values

# %%
df2['Age']=df2['Age'].astype(int)  # Type conversion - converting 'Age' column to integer type

# %%
df2['Age']
# Out:
# 0    25
# 2    30
# 4    22
# 6    25
# 7    25
# Name: Age, dtype: int64

# %% [markdown]
# 3 functions
#
# .apply()
#
# .map()
#
# .replace()

# %%
df2['Age Group']=df2['Age'].apply(lambda x: 'Adult' if x >= 25 else 'Minor')  # Creating a new column based on a condition

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York      F  alice@example.com  01-05-2021     Adult
# 2    Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 4  David   22       Mumbai      M  david@example.com  12-11-2019     Minor
# 6  Alice   25     New York      F  alice@example.com  01-05-2021     Adult
# 7  Alice   25     New York      F  alice@example.com  01-05-2021     Adult

# %%
gender_map ={'M':'Male', 'F':'Female'}  #
df["Gender"]=df["Gender"].map(gender_map)  # Mapping values in the

# %%
df
# Out:
#       Name   Age         City  Gender              Email   Join Date
# 0    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 4    David  22.0       Mumbai    Male  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi  Female     eve@domain.com         NaN
# 6    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 7    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021

# %%
df['City'].replace({'Delhi': 'New Delhi', 'Mumbai': 'Bombay'}, inplace=True)  # Replacing values in the 'City' column

# %%
df
# Out:
#       Name   Age         City  Gender              Email   Join Date
# 0    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 1  Charlie   NaN    New Delhi    Male    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 3  Charlie   NaN    New Delhi    Male    charlie@example  20-07-2021
# 4    David  22.0       Bombay    Male  david@example.com  12-11-2019
# 5      NaN  28.0    New Delhi  Female     eve@domain.com         NaN
# 6    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 7    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 8  Charlie   NaN    New Delhi    Male    charlie@example  20-07-2021
